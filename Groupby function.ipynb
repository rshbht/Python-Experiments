# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import sklearn

# %%
nba_data=pd.read_csv('datas.csv')

# %%
gp=nba_data.groupby('Team')
gp.first()
# Out:
#                                          Name  Number Position  Age Height  \
# Team
# Atlanta Hawks                   Kent Bazemore      24       SF   26    6-5
# Boston Celtics                  Avery Bradley       0       PG   25    6-2
# Brooklyn Nets                Bojan Bogdanovic      44       SG   27    6-8
# Charlotte Hornets               Nicolas Batum       5       SG   27    6-8
# Chicago Bulls                Cameron Bairstow      41       PF   25    6-9
# Cleveland Cavaliers       Matthew Dellavedova       8       PG   25    6-4
# Dallas Mavericks              Justin Anderson       1       SG   22    6-6
# Denver Nuggets                 Darrell Arthur       0       PF   28    6-9
# Detroit Pistons                  Joel Anthony      50        C   33    6-9
# Golden State Warriors         Leandro Barbosa      19       SG   33    6-3
# Houston Rockets                  Trevor Ariza       1       SF   30    6-8
# ...

# %%
gp=nba_data.groupby('Team')
gp.first()
gp.get_group('Atlanta Hawks')
# Out:
#                  Name           Team  Number Position  Age Height  Weight  \
# 309     Kent Bazemore  Atlanta Hawks      24       SF   26    6-5     201
# 310  Tim Hardaway Jr.  Atlanta Hawks      10       SG   24    6-6     205
# 311      Kirk Hinrich  Atlanta Hawks      12       SG   35    6-4     190
# 312        Al Horford  Atlanta Hawks      15        C   30   6-10     245
# 313    Kris Humphries  Atlanta Hawks      43       PF   31    6-9     235
# 314       Kyle Korver  Atlanta Hawks      26       SG   35    6-7     212
# 315      Paul Millsap  Atlanta Hawks       4       PF   31    6-8     246
# 316      Mike Muscala  Atlanta Hawks      31       PF   24   6-11     240
# 317   Lamar Patterson  Atlanta Hawks      13       SG   24    6-5     225
# 318   Dennis Schroder  Atlanta Hawks      17       PG   22    6-1     172
# 319        Mike Scott  Atlanta Hawks      32       PF   27    6-8     237
# 320   Thabo Sefolosha  Atlanta Hawks      25       SF   32    6-7     220
# ...

# %%
teamavg=nba_data.groupby("Team")["Salary"].mean()
print(teamavg)
# Out:
# Team
# Atlanta Hawks             4.860197e+06
# Boston Celtics            4.181505e+06
# Brooklyn Nets             3.501898e+06
# Charlotte Hornets         5.222728e+06
# Chicago Bulls             5.785559e+06
# Cleveland Cavaliers       7.642049e+06
# Dallas Mavericks          4.746582e+06
# Denver Nuggets            4.294424e+06
# Detroit Pistons           4.477884e+06
# Golden State Warriors     5.924600e+06
# Houston Rockets           5.018868e+06
# Indiana Pacers            4.450122e+06
# Los Angeles Clippers      6.323643e+06
# Los Angeles Lakers        4.784695e+06
# Memphis Grizzlies         5.467920e+06
# Miami Heat                6.347359e+06
# Milwaukee Bucks           4.350220e+06
# Minnesota Timberwolves    4.593054e+06
# New Orleans Pelicans      4.355304e+06
# New York Knicks           4.581494e+06
# Oklahoma City Thunder     6.251020e+06
# Orlando Magic             4.297248e+06
# Philadelphia 76ers        2.213778e+06
# Phoenix Suns              4.229676e+06
# ...

# %%
teamcount=nba_data.groupby("Age")["Name"].count()
teamcount
# Out:
# Age
# 19     2
# 20    19
# 21    19
# 22    26
# 23    41
# 24    47
# 25    45
# 26    36
# 27    41
# 28    31
# 29    28
# 30    31
# 31    22
# 32    13
# 33    14
# 34    10
# 35     9
# 36    10
# 37     4
# 38     4
# 39     2
# 40     3
# Name: Name, dtype: int64

# %%
eachteam=nba_data.groupby(["Team","Age"])["Name"].count()
eachteam
# Out:
# Team                Age
# Atlanta Hawks       22     1
#                     24     4
#                     26     1
#                     27     2
#                     30     1
#                           ..
# Washington Wizards  29     1
#                     30     3
#                     32     1
#                     33     2
#                     34     1
# Name: Name, Length: 288, dtype: int64

# %%
teamcount.plot.bar()
